# %%
import pandas as pd
import numpy as np
np.set_printoptions(suppress=False, precision=3)

# %%
file =  r'C:\Users\jimmy\Documents\Data Projects\Project\Financial Transactions Project\data\transactions_data.csv'
# Load the dataset
transactions = pd.read_csv(file)
transactions.head()
# Out:
#         id                 date  client_id  card_id   amount  \
# 0  7475327  2010-01-01 00:01:00       1556     2972  $-77.00
# 1  7475328  2010-01-01 00:02:00        561     4575   $14.57
# 2  7475329  2010-01-01 00:02:00       1129      102   $80.00
# 3  7475331  2010-01-01 00:05:00        430     2860  $200.00
# 4  7475332  2010-01-01 00:06:00        848     3915   $46.41
#
#             use_chip  merchant_id merchant_city merchant_state      zip   mcc  \
# 0  Swipe Transaction        59935        Beulah             ND  58523.0  5499
# 1  Swipe Transaction        67570    Bettendorf             IA  52722.0  5311
# 2  Swipe Transaction        27092         Vista             CA  92084.0  4829
# 3  Swipe Transaction        27092   Crown Point             IN  46307.0  4829
# 4  Swipe Transaction        13051       Harwood             MD  20776.0  5813
#
#   errors
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN

# %%
users = pd.read_csv(r'  C:\Users\jimmy\Documents\Data Projects\Project\Financial Transactions Project\data\users_data.csv')
users.head()
# Out:
#      id  current_age  retirement_age  birth_year  birth_month  gender  \
# 0   825           53              66        1966           11  Female
# 1  1746           53              68        1966           12  Female
# 2  1718           81              67        1938           11  Female
# 3   708           63              63        1957            1  Female
# 4  1164           43              70        1976            9    Male
#
#                     address  latitude  longitude per_capita_income  \
# 0             462 Rose Lane     34.15    -117.76            $29278
# 1    3606 Federal Boulevard     40.76     -73.74            $37891
# 2           766 Third Drive     34.02    -117.89            $22681
# 3          3 Madison Street     40.71     -73.99           $163145
# 4  9620 Valley Stream Drive     37.76    -122.44            $53797
#
#   yearly_income total_debt  credit_score  num_credit_cards
# 0        $59696    $127613           787                 5
# ...

# %%
cards = pd.read_csv(r'C:\Users\jimmy\Documents\Data Projects\Project\Financial Transactions Project\data\cards_data.csv')
cards.head()
# Out:
#      id  client_id  card_brand        card_type       card_number  expires  \
# 0  4524        825        Visa            Debit  4344676511950444  12/2022
# 1  2731        825        Visa            Debit  4956965974959986  12/2020
# 2  3701        825        Visa            Debit  4582313478255491  02/2024
# 3    42        825        Visa           Credit  4879494103069057  08/2024
# 4  4659        825  Mastercard  Debit (Prepaid)  5722874738736011  03/2009
#
#    cvv has_chip  num_cards_issued credit_limit acct_open_date  \
# 0  623      YES                 2       $24295        09/2002
# 1  393      YES                 2       $21968        04/2014
# 2  719      YES                 2       $46414        07/2003
# 3  693       NO                 1       $12400        01/2003
# 4   75      YES                 1          $28        09/2008
#
#    year_pin_last_changed card_on_dark_web
# 0                   2008               No
# 1                   2014               No
# ...

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 2000 non-null   int64
#  1   current_age        2000 non-null   int64
#  2   retirement_age     2000 non-null   int64
#  3   birth_year         2000 non-null   int64
#  4   birth_month        2000 non-null   int64
#  5   gender             2000 non-null   object
#  6   address            2000 non-null   object
#  7   latitude           2000 non-null   float64
#  8   longitude          2000 non-null   float64
#  9   per_capita_income  2000 non-null   object
#  10  yearly_income      2000 non-null   object
#  11  total_debt         2000 non-null   object
#  12  credit_score       2000 non-null   int64
#  13  num_credit_cards   2000 non-null   int64
# dtypes: float64(2), int64(7), object(5)
# memory usage: 218.9+ KB

# %%
transactions.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13305915 entries, 0 to 13305914
# Data columns (total 12 columns):
#  #   Column          Non-Null Count     Dtype
# ---  ------          --------------     -----
#  0   id              13305915 non-null  int64
#  1   date            13305915 non-null  object
#  2   client_id       13305915 non-null  int64
#  3   card_id         13305915 non-null  int64
#  4   amount          13305915 non-null  object
#  5   use_chip        13305915 non-null  object
#  6   merchant_id     13305915 non-null  int64
#  7   merchant_city   13305915 non-null  object
#  8   merchant_state  11742215 non-null  object
#  9   zip             11653209 non-null  float64
#  10  mcc             13305915 non-null  int64
#  11  errors          211393 non-null    object
# dtypes: float64(1), int64(5), object(6)
# memory usage: 1.2+ GB

# %%
transactions.describe(include='all')
# Out:
#                   id                 date     client_id       card_id  \
# count   1.330592e+07             13305915  1.330592e+07  1.330592e+07
# unique           NaN              4136496           NaN           NaN
# top              NaN  2016-03-03 11:42:00           NaN           NaN
# freq             NaN                   18           NaN           NaN
# mean    1.558402e+07                  NaN  1.026812e+03  3.475268e+03
# std     4.704499e+06                  NaN  5.816386e+02  1.674356e+03
# min     7.475327e+06                  NaN  0.000000e+00  0.000000e+00
# 25%     1.150604e+07                  NaN  5.190000e+02  2.413000e+03
# 50%     1.557087e+07                  NaN  1.070000e+03  3.584000e+03
# 75%     1.965361e+07                  NaN  1.531000e+03  4.901000e+03
# max     2.376187e+07                  NaN  1.998000e+03  6.144000e+03
#
#           amount           use_chip   merchant_id merchant_city  \
# ...

# %%
users.describe(include='all')
# Out:
#                  id  current_age  retirement_age   birth_year  birth_month  \
# count   2000.000000  2000.000000     2000.000000  2000.000000  2000.000000
# unique          NaN          NaN             NaN          NaN          NaN
# top             NaN          NaN             NaN          NaN          NaN
# freq            NaN          NaN             NaN          NaN          NaN
# mean     999.500000    45.391500       66.237500  1973.803000     6.439000
# std      577.494589    18.414092        3.628867    18.421234     3.565338
# min        0.000000    18.000000       50.000000  1918.000000     1.000000
# 25%      499.750000    30.000000       65.000000  1961.000000     3.000000
# 50%      999.500000    44.000000       66.000000  1975.000000     7.000000
# 75%     1499.250000    58.000000       68.000000  1989.000000    10.000000
# max     1999.000000   101.000000       79.000000  2002.000000    12.000000
#
#         gender              address     latitude    longitude  \
# ...

# %%
users.value_counts('num_credit_cards', normalize=True).mul(100).map('{:.2f}%'.format)
# Out:
# num_credit_cards
# 3    22.45%
# 1    20.80%
# 2    19.40%
# 4    18.80%
# 5    10.30%
# 6     5.25%
# 7     2.00%
# 8     0.85%
# 9     0.15%
# Name: proportion, dtype: object

# %%
users.head()
# Out:
#      id  current_age  retirement_age  birth_year  birth_month  gender  \
# 0   825           53              66        1966           11  Female
# 1  1746           53              68        1966           12  Female
# 2  1718           81              67        1938           11  Female
# 3   708           63              63        1957            1  Female
# 4  1164           43              70        1976            9    Male
#
#                     address  latitude  longitude per_capita_income  \
# 0             462 Rose Lane     34.15    -117.76            $29278
# 1    3606 Federal Boulevard     40.76     -73.74            $37891
# 2           766 Third Drive     34.02    -117.89            $22681
# 3          3 Madison Street     40.71     -73.99           $163145
# 4  9620 Valley Stream Drive     37.76    -122.44            $53797
#
#   yearly_income total_debt  credit_score  num_credit_cards
# 0        $59696    $127613           787                 5
# ...

# %%
transactions.sample(5)
# Out:
#                 id                 date  client_id  card_id   amount  \
# 6994386   15989689  2015-04-22 22:25:00        194     4273  $-66.00
# 4867728   13385413  2013-10-02 05:58:00       1382     5262   $41.32
# 2857990   10935625  2012-04-01 17:13:00        846     3886  $114.60
# 8117214   17366232  2016-02-11 10:53:00       1913     5877    $7.99
# 11552719  21593247  2018-07-29 13:01:00        491     2483   $37.79
#
#                     use_chip  merchant_id  merchant_city merchant_state  \
# 6994386     Chip Transaction        59935  Hartford City             IN
# 4867728    Swipe Transaction        49789         Dallas             TX
# 2857990   Online Transaction        80770         ONLINE            NaN
# 8117214     Chip Transaction        69972          Miami             FL
# 11552719    Chip Transaction        50867  Mission Viejo             CA
#
#               zip   mcc errors
# 6994386   47348.0  5499    NaN
# 4867728   75253.0  5541    NaN
# ...

# %%
transactions.loc[transactions['id'] == 7475329,:]
# Out:
#         id                 date  client_id  card_id  amount  \
# 2  7475329  2010-01-01 00:02:00       1129      102  $80.00
#
#             use_chip  merchant_id merchant_city merchant_state      zip   mcc  \
# 2  Swipe Transaction        27092         Vista             CA  92084.0  4829
#
#   errors
# 2    NaN

# %%
transactions_filtered = transactions.loc[transactions['date'].str[:4].isin(['2017','2018','2019']), :].copy()

# %%
transactions_filtered.sample(5)
# Out:
#                 id                 date  client_id  card_id   amount  \
# 10439340  20220932  2017-10-11 14:50:00        677     5317  $105.90
# 12604643  22895296  2019-05-01 12:28:00        261     2706   $60.00
# 10895783  20782588  2018-02-07 15:25:00        748     1067   $61.00
# 11339359  21329695  2018-06-03 18:46:00         37     1230   $67.84
# 10966958  20870156  2018-02-26 10:29:00        511     2212   $75.60
#
#                     use_chip  merchant_id    merchant_city merchant_state  \
# 10439340   Swipe Transaction        20561       Saint Paul             MN
# 12604643    Chip Transaction        27092  North Las Vegas             NV
# 10895783    Chip Transaction        43293          Houston             TX
# 11339359  Online Transaction        73186           ONLINE            NaN
# 10966958  Online Transaction        88459           ONLINE            NaN
#
#               zip   mcc errors
# 10439340  55119.0  5912    NaN
# 12604643  89032.0  4829    NaN
# ...

# %%
transactions_filtered.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3954066 entries, 9351849 to 13305914
# Data columns (total 12 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   id              3954066 non-null  int64
#  1   date            3954066 non-null  object
#  2   client_id       3954066 non-null  int64
#  3   card_id         3954066 non-null  int64
#  4   amount          3954066 non-null  object
#  5   use_chip        3954066 non-null  object
#  6   merchant_id     3954066 non-null  int64
#  7   merchant_city   3954066 non-null  object
#  8   merchant_state  3473293 non-null  object
#  9   zip             3444171 non-null  float64
#  10  mcc             3954066 non-null  int64
#  11  errors          62903 non-null    object
# dtypes: float64(1), int64(5), object(6)
# memory usage: 392.2+ MB

# %%
transactions.loc[transactions['amount'].str.contains('-'), ['amount','use_chip']].head()
# Out:
#        amount           use_chip
# 0     $-77.00  Swipe Transaction
# 19    $-64.00  Swipe Transaction
# 50    $-78.00  Swipe Transaction
# 81   $-460.00  Swipe Transaction
# 114  $-147.00  Swipe Transaction

# %%
transactions.columns
# Out:
# Index(['id', 'date', 'client_id', 'card_id', 'amount', 'use_chip',
#        'merchant_id', 'merchant_city', 'merchant_state', 'zip', 'mcc',
#        'errors'],
#       dtype='object')

# %%
pd.to_datetime(cards['acct_open_date'], format='%Y-%m', errors='coerce')
# Out:
# 0      NaT
# 1      NaT
# 2      NaT
# 3      NaT
# 4      NaT
#         ..
# 6141   NaT
# 6142   NaT
# 6143   NaT
# 6144   NaT
# 6145   NaT
# Name: acct_open_date, Length: 6146, dtype: datetime64[ns]

# %%
cards.sample(5)
# Out:
#         id  client_id  card_brand        card_type       card_number  expires  \
# 3419  5017       1295        Visa           Credit  4892675252828860  02/2024
# 757   3379        346  Mastercard  Debit (Prepaid)  5511433440463506  12/2023
# 1864  6133        425  Mastercard            Debit  5309902802047025  02/2020
# 4693   895       1458        Visa           Credit  4733347153706598  07/2020
# 5314  2293        889        Visa           Credit  4476864861762314  09/2022
#
#       cvv has_chip  num_cards_issued credit_limit acct_open_date  \
# 3419  823      YES                 1        $9900        10/2004
# 757   463       NO                 2          $86        06/2008
# 1864  972      YES                 1       $43973        12/2017
# 4693  265      YES                 2        $8000        01/2020
# 5314  669      YES                 1       $14700        03/2011
#
#       year_pin_last_changed card_on_dark_web
# 3419                   2014               No
# ...

# %%
print(cards['id'].nunique())
print(cards['client_id'].nunique())
# Out:
# 6146
# 2000

# %%
transactions.head()
# Out:
#         id                 date  client_id  card_id   amount  \
# 0  7475327  2010-01-01 00:01:00       1556     2972  $-77.00
# 1  7475328  2010-01-01 00:02:00        561     4575   $14.57
# 2  7475329  2010-01-01 00:02:00       1129      102   $80.00
# 3  7475331  2010-01-01 00:05:00        430     2860  $200.00
# 4  7475332  2010-01-01 00:06:00        848     3915   $46.41
#
#             use_chip  merchant_id merchant_city merchant_state      zip   mcc  \
# 0  Swipe Transaction        59935        Beulah             ND  58523.0  5499
# 1  Swipe Transaction        67570    Bettendorf             IA  52722.0  5311
# 2  Swipe Transaction        27092         Vista             CA  92084.0  4829
# 3  Swipe Transaction        27092   Crown Point             IN  46307.0  4829
# 4  Swipe Transaction        13051       Harwood             MD  20776.0  5813
#
#   errors
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN

# %%
transactions.loc[transactions['client_id'] == 1458, :].head()
# Out:
#             id                 date  client_id  card_id   amount  \
# 900    7476398  2010-01-01 09:29:00       1458      117    $5.63
# 3539   7479533  2010-01-02 02:07:00       1458      117  $103.58
# 3541   7479535  2010-01-02 02:15:00       1458      117   $85.01
# 7189   7483885  2010-01-03 08:23:00       1458      117    $3.85
# 10325  7487669  2010-01-04 07:45:00       1458      117  $163.33
#
#                 use_chip  merchant_id merchant_city merchant_state      zip  \
# 900    Swipe Transaction        61195   New Orleans             LA  70119.0
# 3539   Swipe Transaction        20561   New Orleans             LA  70119.0
# 3541   Swipe Transaction        20561   New Orleans             LA  70119.0
# 7189   Swipe Transaction        32671   New Orleans             LA  70119.0
# 10325  Swipe Transaction        86616   New Orleans             LA  70121.0
#
#         mcc                errors
# 900    5541                   NaN
# 3539   5912                   NaN
# ...

# %%
users.head()
# Out:
#      id  current_age  retirement_age  birth_year  birth_month  gender  \
# 0   825           53              66        1966           11  Female
# 1  1746           53              68        1966           12  Female
# 2  1718           81              67        1938           11  Female
# 3   708           63              63        1957            1  Female
# 4  1164           43              70        1976            9    Male
#
#                     address  latitude  longitude per_capita_income  \
# 0             462 Rose Lane     34.15    -117.76            $29278
# 1    3606 Federal Boulevard     40.76     -73.74            $37891
# 2           766 Third Drive     34.02    -117.89            $22681
# 3          3 Madison Street     40.71     -73.99           $163145
# 4  9620 Valley Stream Drive     37.76    -122.44            $53797
#
#   yearly_income total_debt  credit_score  num_credit_cards
# 0        $59696    $127613           787                 5
# ...

# %%
users['id'].nunique()
# Out:
# 2000

# %%
transactions.head()
# Out:
#         id                 date  client_id  card_id   amount  \
# 0  7475327  2010-01-01 00:01:00       1556     2972  $-77.00
# 1  7475328  2010-01-01 00:02:00        561     4575   $14.57
# 2  7475329  2010-01-01 00:02:00       1129      102   $80.00
# 3  7475331  2010-01-01 00:05:00        430     2860  $200.00
# 4  7475332  2010-01-01 00:06:00        848     3915   $46.41
#
#             use_chip  merchant_id merchant_city merchant_state      zip   mcc  \
# 0  Swipe Transaction        59935        Beulah             ND  58523.0  5499
# 1  Swipe Transaction        67570    Bettendorf             IA  52722.0  5311
# 2  Swipe Transaction        27092         Vista             CA  92084.0  4829
# 3  Swipe Transaction        27092   Crown Point             IN  46307.0  4829
# 4  Swipe Transaction        13051       Harwood             MD  20776.0  5813
#
#   errors
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN

# %%
transactions.loc[transactions['merchant_id'] == 74934].groupby('merchant_id')['zip'].nunique().reset_index().rename(columns={'zip': 'unique_zip_count'})
# Out:
#    merchant_id  unique_zip_count
# 0        74934                 2

# %%
transactions['merchant_state'].nunique()
# Out:
# 199

# %%
transactions.value_counts(['merchant_id','zip'] ).sort_values(ascending=False).head(10)
# Out:
# merchant_id  zip
# 74934        94606.0    14181
# 39991        48146.0    14143
# 57133        96792.0    14120
# 50867        51023.0    13985
# 78644        89148.0    13830
# 56431        98516.0    13804
# 27092        38116.0    13725
# 59935        51022.0    13508
#              98516.0    13232
# 88852        95687.0    13045
# Name: count, dtype: int64

# %%
transactions.loc[transactions['merchant_id'] == 74934].value_counts('zip').sort_values(ascending=False).head(10)
# Out:
# zip
# 94606.0    14181
# 12158.0        6
# Name: count, dtype: int64

# %%
transactions_filtered['date'].str[17:].value_counts().sort_index()
# Out:
# date
# 00    3954066
# Name: count, dtype: int64

# %%
import setup_logging from utils.setup_logging
# Out:
#   Cell In[103], line 1
#     import setup_logging from utils.setup_logging
#     ^
# SyntaxError: Did you mean to use 'from ... import ...' instead?
